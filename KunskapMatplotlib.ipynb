# %% [markdown]
# # Matplotlib
# Read the tutorials: "Basic Usage" and "Pyplot Tutorial" in the link: https://matplotlib.org/stable/tutorials/index.html before solving the exercises below. The "Pyplot Tutorial" you do not read in detail but it is good to know about since the fact that there are two approaches to plotting can be confusing if you are not aware of both of the approaches.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Plotting in Matplotlib can be done in either of two ways, which ones? Which way is the recommended approach?

# %%
#Pyplot = funtional interface
#OO = Object-Oriented interface 

#It is recommended using the OO-approach because it is more customizable and flexible than pyplot. 
#You can reuse the code and it can be used for bigger projects
#Pyplot is a simpler approach and should only be used for simpler tasks and to experiment with code

# %% [markdown]
# ### Explain shortly what a figure, axes, axis and an artist is in Matplotlib.

# %%
#Figure: The foundation for plotting data in Matplotlib.
         #For example, if plotting were to paint a painting, the figure is the canvas of the painting   
#Axes: The region of the figure where we are plotting. In the above example, the place on the canvas where we are painting. 
#Axis: The Axes contains axis. For example x-axis and y-axis. On each axis we set the scale of the axis and according to the data it 
       #generate "ticks" which we can lable 
#Artist: Everything that is visible on the figure (both graphical figures on the figure, and the "container" ie the axes, axis etc)

# %% [markdown]
# ### When plotting in Matplotlib, what is the expected input data type?

# %%
#Basically numpy.arrays or objects that can be passed to numpy.asarray. Array-like classes should according to convention
#first be converted to numpy.array

# %% [markdown]
# ### Create a plot of the function y = x^2 [from -4 to 4, hint use the np.linspace function] both in the object-oriented approach and the pyplot approach. Your plot should have a title and axis-labels.

# %%
#OO
x = np.linspace(-4, 4) 
y = x**2

fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_title('y = x^2')
ax.set_xlabel('x')
ax.set_ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
#Pyplot
plt.plot(x, y)
plt.title("y = x^2")
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# ### Create a figure containing 2  subplots where the first is a scatter plot and the second is a bar plot. You have the data below.

# %%
# Data for scatter plot
np.random.seed(15)
random_data_x = np.random.randn(1000)
random_data_y = np.random.randn(1000)
x = np.linspace(-2, 2, 100)
y = x**2


# Data for bar plot
fruit_data = {'grapes': 22, 'apple': 8, 'orange': 15, 'lemon': 20, 'lime': 25}
names = list(fruit_data.keys())
values = list(fruit_data.values())

# %%
fig, ax = plt.subplots (1, 2, layout = "constrained")
fig.suptitle('Two subplots', size = 20)
ax[0].scatter(random_data_x, random_data_y, color = "orange")
ax[0].set_title('Random scatter Plot')

ax[1].bar(names, values)
ax[1].set_title('Fruit bar Plot')
# Out:
# Text(0.5, 1.0, 'Fruit bar Plot')
